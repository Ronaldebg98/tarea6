# %% [markdown]
# # Población

# %%
import PoblaciónMendeliana

# %%
from PoblaciónMendeliana import build_population

# %%
build_population(N = 500, p = 0.21)
# Out:
# [('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('a', 'a'),
# ...

# %%
help(build_population)
# Out:
# Help on function build_population in module PoblaciónMendeliana:
#
# build_population(N, p)
#     Se crea una población en la cual N es el número de individuos. Además cada individuo tiene 2 cromosomas
#     que contienen un alelo "A" o un alelo "a", con una probabilidad p de 1-p. La población se expresará en
#     una lista de tuplas.

# %% [markdown]
# # Conteo de Frecuencias y Propoción de alelos

# %%
from PoblaciónMendeliana import compute_frequencies

# %%
my_pop = build_population(500, 0.21)

# %%
fmy_pop = compute_frequencies(my_pop)
print(fmy_pop)
print((500-fmy_pop["AA"])/500)
# Out:
# {'AA': 16, 'aa': 300, 'Aa': 95, 'aA': 89}
# 0.968

# %%
fmy_pop = compute_frequencies(my_pop)
print(fmy_pop)
print((500-fmy_pop["aa"])/500)
# Out:
# {'AA': 16, 'aa': 300, 'Aa': 95, 'aA': 89}
# 0.4

# %%
fmy_pop = compute_frequencies(my_pop)
print(fmy_pop)
print((500-fmy_pop["Aa"])/500)
# Out:
# {'AA': 16, 'aa': 300, 'Aa': 95, 'aA': 89}
# 0.81

# %%
fmy_pop = compute_frequencies(my_pop)
print(fmy_pop)
print((500-fmy_pop["aA"])/500)
# Out:
# {'AA': 16, 'aa': 300, 'Aa': 95, 'aA': 89}
# 0.822

# %%
help(compute_frequencies)
# Out:
# Help on function compute_frequencies in module PoblaciónMendeliana:
#
# compute_frequencies(population)
#     Aquí se hace un conteo del genotipo.

# %% [markdown]
# # Reproducción de la Población

# %%
from PoblaciónMendeliana import reproduce_population

# %%
print(compute_frequencies(my_pop))
new_pop = reproduce_population(my_pop)
new_pop2 = reproduce_population(new_pop)
print(compute_frequencies(new_pop))
print(compute_frequencies(new_pop2))
# Out:
# {'AA': 16, 'aa': 300, 'Aa': 95, 'aA': 89}
# {'AA': 30, 'aa': 311, 'Aa': 77, 'aA': 82}
# {'AA': 17, 'aa': 305, 'Aa': 101, 'aA': 77}

# %%
# Out:
#   File "C:\Users\pc\AppData\Local\Temp/ipykernel_6436/581360786.py", line 1
#     for compute_frequencies(my_pop)
#         ^
# SyntaxError: cannot assign to function call

# %% [markdown]
# # No pude crear el for para las 500 generaciones :c
